# %% [markdown]
# <a href="https://colab.research.google.com/github/deemanth-05/HRV/blob/main/HRV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install IPython-autotime

# %% [markdown]
# IMPORT NECESSARY LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
#import math
#from math import lyapunov_exponent
df = pd.read_csv('/content/sample_data/Bvp signal with subject id and labels.csv')
# Out:
# <ipython-input-2-b9b5bf0a5418>:9: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/sample_data/Bvp signal with subject id and labels.csv')

# %%
df.head()
# Out:
#   Subject_id         BVP Labels
# 0          1  -62.381711    G-1
# 1          1    9.484982    G-1
# 2          1   85.229720    G-1
# 3          1  167.234760    G-1
# 4          1  256.483159    G-1
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
# ...

# %%
df.shape
# Out:
# (4240441, 3)

# %%
df.isnull().sum()
# Out:
# Subject_id    0
# BVP           0
# Labels        1
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#         Subject_id         BVP   Labels
# 0                1  -62.381711      G-1
# 1                1    9.484982      G-1
# 2                1   85.229720      G-1
# 3                1  167.234760      G-1
# 4                1  256.483159      G-1
# ...            ...         ...      ...
# 4240435         23   -2.203116  Control
# 4240436         23   -2.698745  Control
# 4240437         23   -3.151028  Control
# 4240438         23   -3.505630  Control
# 4240439         23   -3.708828  Control
#
# [4240440 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Subject_id    0
# BVP           0
# Labels        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4240440 entries, 0 to 4240439
# Data columns (total 3 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Subject_id  object
#  1   BVP         float64
#  2   Labels      object
# dtypes: float64(1), object(2)
# memory usage: 129.4+ MB

# %% [markdown]
# PRE - PROCESSING

# %%
#df['Subject_id'] = df['Subject_id'].astype(int)
df['BVP'] = df['BVP'].astype(float)
df['Labels'] = df['Labels'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4240440 entries, 0 to 4240439
# Data columns (total 3 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Subject_id  object
#  1   BVP         float64
#  2   Labels      category
# dtypes: category(1), float64(1), object(1)
# memory usage: 101.1+ MB

# %% [markdown]
# LOGISTIC MAP

# %%
logistic_map = np.zeros(len(df))
for i in range(len(df)):
  logistic_map[i] = 4 * df['BVP'][i] * (1 - df['BVP'][i])

# %% [markdown]
# CHAOS REALTED METRICS

# %%
#lyapunov_exponents = np.zeros(len(df))
#for i in range(len(df)):
#  lyapunov_exponents[i] = lyapunov_exponent(logistic_map[i])

# %% [markdown]
# DERIVING HRV FEATURES

# %%
#hrv_features = []
#hrv_features = get_hrv_features(df['BVP'])

#----------------------------------------------------------------------------------------------------------------------------------#

#hrv_features = []
#for i in range(len(df)):
#    hrv_features.append(get_hrv_features(df['BVP'][i]))

# %% [markdown]
# # TRAIN A CLASSIFICATION MODEL

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Subject_id'], df['Labels'], test_size=0.2)
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-749dace43c08> in <cell line: 4>()
#       2 X_train, X_test, y_train, y_test = train_test_split(df['Subject_id'], df['Labels'], test_size=0.2)
#       3 model = LogisticRegression()
# ----> 4 model.fit(X_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
# ...

# %% [markdown]
# **PREDICTION**

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
